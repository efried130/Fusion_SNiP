# %%
#Aquasat exploration

# %%
library(tzdb,lib.loc = "/nas/cee-water/cjgleason/r-lib/")
library(withr,lib.loc = "/nas/cee-water/cjgleason/r-lib/")
library(readr,lib.loc = "/nas/cee-water/cjgleason/r-lib/")
library(dplyr,lib.loc = "/nas/cee-water/cjgleason/r-lib/")
library(ggplot2,lib.loc = "/nas/cee-water/cjgleason/r-lib/")
library(labeling,lib.loc = "/nas/cee-water/cjgleason/r-lib/")
library(farver,lib.loc = "/nas/cee-water/cjgleason/r-lib/")
library(vroom,lib.loc = "/nas/cee-water/cjgleason/r-lib/")
library(lubridate,lib.loc = "/nas/cee-water/cjgleason/r-lib/")
library(caTools,lib.loc = "/nas/cee-water/cjgleason/r-lib/")

# %%
getwd()
# Out:
# [1] "/nas/cee-water/cjgleason/ellie/SNiP/Aquasat"

# %%
Aquasat <- read.csv("sr_wq_rs_join.csv")

# %%
head(Aquasat)
print(ncol(Aquasat))
print(nrow(Aquasat))
names(Aquasat)
Aquasat %>% 
    count(type)
# Out:
#   system.index SiteID blue blue_sd  date_unity           green green_sd
# 1 1            8348   230  25.89035 2004-08-23T12:00:00Z 243   22.78187
# 2 3            8348   200  23.91702 2001-08-22T12:00:00Z 212   23.64533
# 3 4            8348   543  31.11958 2003-06-25T12:00:00Z 495   31.44690
# 4 6            7889   269  31.26599 1988-07-18T12:00:00Z 270   32.08251
# 5 7            7889   146  18.72004 1990-07-08T12:00:00Z 137   33.13925
# 6 8            7889   369  24.94186 1992-05-26T12:00:00Z 414   28.24199
#   nir      nir_sd   path ... long      TZID             date_utc
# 1 383.0000 30.70424 10   ... -67.82940 America/New_York 2004-08-23T16:00:00Z
# 2 242.0000 23.73033 10   ... -67.82940 America/New_York 2001-08-22T16:00:00Z
# 3 639.0000 33.75664 10   ... -67.82940 America/New_York 2003-06-25T16:00:00Z
# 4 364.4707 56.94264 10   ... -67.58515 America/Moncton  1988-07-18T15:00:00Z
# 5 212.0000 17.41379 10   ... -67.58515 America/Moncton  1990-07-08T15:00:00Z
# 6 651.0000 31.13198 10   ... -67.58515 America/Moncton  1992-05-26T15:00:00Z
#   clouds time                 landsat_id
# 1 17     2004-08-23T15:02:20Z LE07_L1TP_010028_20040823_20160926_01_T1
# 2  6     2001-08-23T14:53:48Z LT05_L1TP_010028_20010823_20160917_01_T1
# 3  3     2003-06-26T14:49:37Z LT05_L1TP_010028_20030626_20160915_01_T1
# 4 26     1988-07-18T14:44:16Z LT05_L1TP_010028_19880718_20161002_01_T1
# 5  4     1990-07-08T14:33:41Z LT05_L1TP_010028_19900708_20160930_01_T1
# 6 23     1992-05-26T14:37:08Z LT05_L1TP_010028_19920526_20160929_01_T1
#   timediff    pwater type id
# 1   0.9610410 97     Lake New
# 2 -22.8968256 97     Lake New
# 3 -22.8271217 97     Lake New
# 4   0.2621853 95     Lake New
# 5   0.4384189 95     Lake New
# 6   0.3809778 95     Lake New
# [1] 43
# [1] 414835
#  [1] "system.index" "SiteID"       "blue"         "blue_sd"      "date_unity"
#  [6] "green"        "green_sd"     "nir"          "nir_sd"       "path"
# [11] "pixelCount"   "qa"           "qa_sd"        "red"          "red_sd"
# [16] "row"          "sat"          "swir1"        "swir1_sd"     "swir2"
# [21] "swir2_sd"     ".geo"         "endtime"      "date"         "date_only"
# [26] "chl_a"        "doc"          "p_sand"       "secchi"       "tis"
# [31] "tss"          "source"       "lat"          "long"         "TZID"
# [36] "date_utc"     "clouds"       "time"         "landsat_id"   "timediff"
# [41] "pwater"       "type"         "id"
#   type     n
# 1               1
# 2 Estuary   77450
# 3 Facility    912
# 4 Lake     259218
# 5 Stream    77254

# %%
AquasatStream <- Aquasat %>%
    filter(type == 'Stream')
nrow(AquasatStream)
# Out:
# [1] 77254

# %%
#Save only stream data to RDS for use with SNiP data
#WQPdata <- saveRDS(AquasatStream, file = "/nas/cee-water/cjgleason/ellie/SNiP/WQPdata/AquasatStream.rds")

# %%
#Visualize for choosing test river
Aquaviz <- AquasatStream %>%
    select(SiteID, tss, date, lat, long, path, row, landsat_id) %>%
    filter(!is.na(tss)) %>%
    group_by(SiteID) %>% 
    summarise(record_count = n()) %>%
    filter(record_count > 100) 
      
Aquaviz
# Out:
#     SiteID               record_count
# 1   21VASWCB-2-JMS157.28 120
# 2   ARDEQH2O_WQX-WHI0025 103
# 3   CBP_WQX-CB1.1        116
# 4   CBP_WQX-CB2.1        124
# 5   CBP_WQX-CB2.2        118
# 6   CBP_WQX-CB3.1        116
# 7   CBP_WQX-CB3.2        128
# 8   CBP_WQX-CB3.3C       127
# 9   CBP_WQX-CB3.3E       104
# 10  CBP_WQX-CB3.3W       104
# 11  CBP_WQX-CB4.1C       126
# 12  CBP_WQX-CB4.1E       104
# 13  CBP_WQX-CB4.2C       136
# 14  CBP_WQX-CB4.2E       116
# 15  CBP_WQX-CB4.2W       107
# 16  CBP_WQX-CB4.3C       134
# 17  CBP_WQX-CB4.3E       109
# 18  CBP_WQX-CB4.4        140
# 19  CBP_WQX-CB5.1        162
# 20  CBP_WQX-CB5.1W       161
# 21  CBP_WQX-CB5.2        141
# 22  CBP_WQX-CB5.3        128
# 23  CBP_WQX-CB5.4        102
# 24  CBP_WQX-CB5.4W       115
# 25  CBP_WQX-EE1.1        137
# 26  CBP_WQX-EE2.1        136
# 27  CBP_WQX-EE2.2        130
# 28  CBP_WQX-ET4.1        106
# 29  CBP_WQX-ET4.2        130
# 30  CBP_WQX-ET5.1        145
# ... ...                  ...
# 50  CBP_WQX-WQN0214      103
# 51  MDDNR-CB5.1W         118
# 52  MDDNR-EE1.1          124
# 53  MDDNR-EE2.1          123
# 54  MDDNR-EE2.2          113
# 55  MDDNR-ET4.2          120
# 56  MDDNR-ET5.1          114
# 57  MDDNR-ET5.2          118
# 58  MDDNR-LE1.2          109
# 59  MDDNR-LE1.3          128
# 60  MDDNR-LE1.4          123
# 61  MDDNR-LE2.2          130
# 62  NJHDG-7              107
# 63  NJHDG-8              123
# 64  USGS-01331095        134
# 65  USGS-01335770        487
# 66  USGS-01357500        325
# 67  USGS-01578310        186
# 68  USGS-02035000        190
# 69  USGS-02215500        101
# 70  USGS-02397530        102
# 71  USGS-04073468        134
# 72  USGS-05325000        162
# 73  USGS-05431017        105
# 74  USGS-05465500        291
# 75  USGS-05559600        410
# 76  USGS-05586100        145
# 77  USGS-06934500        137
# 78  USGS-07381600        161
# 79  USGS-431510077363501 194

# %%
ggplot(Aquaviz, aes(x=SiteID)) + geom_histogram(stat= 'count', color="black", fill="white", bins=50)
# Out:
# Warning message:
# “Ignoring unknown parameters: binwidth, bins, pad”
# plot without title

# %%
#Build a validation/test dataset from TSS Aquasat data

#Get CONUS sites with a lot of data
siteFilter <- AquasatStream %>%
    filter(!is.na(tss)) %>%
    group_by(SiteID) %>% tally(sort = TRUE) %>% filter(n > 50)

#Filter AquasatStream for these sites
aquaValTest <- AquasatStream %>%
    inner_join(siteFilter, by='SiteID')

# %%
#Randomly split and save for training/testing
dataSplitCONUS <- sample.split(aquaValTest,SplitRatio = 0.3)

#subsetting into Train data and saving as RDS
aquaTrainCONUS =subset(aquaValTest,dataSplitCONUS == TRUE)
#aquaTrainCONUS <- saveRDS(aquaTrainCONUS, file = "/nas/cee-water/cjgleason/ellie/SNiP/Aquasat/aquaTrainCONUS.rds")


#subsetting into Test data and saving as RDS
aquaTestCONUS =subset(aquaValTest,dataSplitCONUS ==FALSE)
#aquaTestCONUS <- saveRDS(aquaTrainCONUS, file = "/nas/cee-water/cjgleason/ellie/SNiP/Aquasat/aquaTestCONUS.rds")
